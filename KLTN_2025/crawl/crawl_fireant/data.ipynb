# %%
import pandas as pd

# %%
df = pd.read_excel("news_GAS_fix.xlsx")

# %%
df
# Out:
#            STT                                              title  \
# 0     GAS_0001  GAS: PV GAS đặt mục tiêu ROE bình quân 15 - 20...
# 1     GAS_0002  GAS: Quyết tâm hoàn thành kế hoạch quản trị 20...
# 2     GAS_0003  Cập nhật BCTC quý 2/2025 ngày 17/7: Công ty nh...
# 3     GAS_0004  Thường trực Đảng ủy Petrovietnam làm việc với ...
# 4     GAS_0005  GAS: Đảng bộ PV GAS VUNG TAU hoàn thành xuất s...
# ...        ...                                                ...
# 1054  GAS_1055  Khủng hoảng năng lượng thúc đẩy dòng vốn FDI t...
# 1055  GAS_1056  PSI: Doanh nghiệp dầu khí sẽ hồi phục tích cực...
# 1056  GAS_1057  GAS: PV GAS - Ước tính lợi nhuận quý III/2021 ...
# 1057  GAS_1058              Cổ phiếu khí đốt tăng trưởng nhờ đâu?
# 1058  GAS_1059   Giá khí lên cao nhưng cổ phiếu không còn hấp dẫn
#
#                                                 content  \
# 0     Tổng công ty Khí Việt Nam (PVGAS, mã chứng kho...
# 1     Ngày 14/7, tại TP HCM, Thường trực Đảng ủy Tập...
# ...

# %%
missing_idx = df[df['content'].isna() | (df['content'] == "")].index
print("📌 Index các dòng thiếu content:")
print(missing_idx.tolist())
# Out:
# 📌 Index các dòng thiếu content:
# [12, 15, 23, 40, 58, 62, 63, 70, 74, 82, 350, 385, 391, 510, 562, 564, 565, 569, 581, 597, 598, 600, 603, 606, 607, 608, 610, 611, 618, 624, 632, 639, 645, 646, 648, 649, 652, 653, 656, 660, 664, 667, 668, 670, 677, 681, 682, 683, 685, 687, 697, 699, 707, 710, 712, 717, 720, 721, 722, 723, 730, 737, 747, 748, 753, 754, 758, 760, 765, 774, 782, 783, 788, 802, 807, 809, 816, 817, 827, 831, 832, 844, 856, 858, 865, 875, 878, 893, 897, 901, 904, 915, 918, 920, 930, 933, 948, 949, 950, 951, 952, 957, 958, 959, 961, 965, 967, 977, 979, 985, 986, 990, 991, 993, 999, 1002, 1004, 1006, 1009, 1014, 1019, 1020, 1023, 1026, 1030, 1034]

# %%
missing_idx = df[df['ai_summary'].isna() | (df['ai_summary'] == "")].index
print("📌 Index các dòng thiếu ai_summary:")
print(missing_idx.tolist())
# Out:
# 📌 Index các dòng thiếu ai_summary:
# [99, 155, 159]
